# %%
import pandas as pd

# %%
df = pd.read_excel('D://code//data//private_finn//2-8 AOI第一盤CAM5數據.xlt', encoding = 'big5', header = None)

# %%
#df

# %%
for i in df.iteritems():
    print(list(i)[1][2])
# Out:
# 左上 1PIN(上限0.18)
# 0.22
# 0.173
# 上排缺膠溢膠異物2-10(寬度下限0.18：各數下限：2)
# 2
# 0.211
# 0.205
# 0.205
# 2
# 0.218
# 0.212
# 0.212
# 2
# 0.211
# 0.21
# 0.21
# 2
# 0.215
# 0.211
# 0.211
# 2
# 0.218
# 0.213
# 0.213
# 2
# 0.214
# 0.21
# 0.21
# 2
# 0.215
# 0.213
# 0.213
# 2
# 0.22
# 0.215
# 0.215
# 2
# 0.218
# 0.201
# 0.201
# 2
# 0.219
# 0.217
# 0.217
# 右上 12PIN(上限0.18)
# 0.219
# 0.182
# 左下 13PIN(上限0.18)
# 0.207
# 0.207
# 下排缺膠溢膠異物14-23(寬度下限0.18：各數下限：2)
# 2
# 0.213
# 0.211
# 0.211
# 2
# 0.21
# 0.209
# 0.209
# 2
# 0.212
# 0.211
# 0.211
# 2
# 0.212
# 0.209
# 0.209
# 2
# 0.209
# 0.207
# 0.207
# 2
# 0.214
# 0.21
# 0.21
# 2
# 0.213
# 0.208
# 0.208
# 2
# 0.21
# 0.208
# 0.208
# 2
# 0.215
# 0.213
# 0.213
# 右下 24PIN(上限0.18)
# 0.218
# 0.218
# 上間距 1-3PIN(上限0.445:下限0.36)
# 0.404
# 0.392
# 0.405
# 上間距 4-6PIN(上限0.445:下限0.36)
# 0.397
# 0.401
# 0.398
# 上間距 7-9PIN(上限0.445:下限0.36)
# 0.403
# 0.396
# 0.404
# 上間距 10-11PIN(上限0.445:下限0.36)
# 0.391
# 0.406
# 下間距 1-3PIN(上限0.445:下限0.36)
# 0.401
# 0.404
# 0.401
# 下間距 4-6PIN(上限0.445:下限0.36)
# 0.401
# 0.408
# 0.393
# 下間距 7-9PIN(上限0.445:下限0.36)
# 0.409
# 0.401
# 0.403
# 下間距 10-11PIN(上限0.445:下限0.36)
# 0.405
# 0.397
# 左上HD多料(上限0.03)
# -0.004
# 右上HD多料(上限0.03)
# -0.006
# 左下HD多料(上限0.03)
# 0.0
# 右下HD多料(上限0.03)
# 0
# 台階缺膠(上限40)
# 0
# 0
# 多料("0-1"上限0.08："2"上限2.47)
# 0.009
# 0.009
# 1.416
# 頭部缺膠(上限300)
# 0
# 尾部缺膠(上限300)
# 0
# 中央缺膠異物(上限60)
# 0
# 外型多膠(上限100)
# 0
# 頂部端子溢膠(上限24：下限24)
# 24
# 前面頂部端子間距異物(1~4)(上限100)
# 0
# 後面頂部端子間距異物(19~24)(上限200)
# 0
# 有無材料(下限1)
# 1
